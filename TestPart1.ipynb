# %% [markdown]
# ## Setup datasets on Colab - only once

# %% [markdown]
# The following code must be executed only the first time that you open Colab; it is needed to unzip the dataset that we provided into your GDrive account so that you can access them in the future
#
# NB: BEFORE running this notebook, you must copy the dataset zip at this [link](https://drive.google.com/file/d/1tQqEyt3go3vMh4fj_LZrRcahoTbzzH-y/view?usp=share_link) into your GDrive. You can use the link by simply clicking 'create a copy'. Make sure that you have enough space in GDrive (roughly 1 GB)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# move into your mounted GDrive filesystem
# %cd /content/drive/MyDrive/Mldl/Project3B/dataset1
 # replace this with path on your GDrive
# Out:
# /content/drive/MyDrive/Mldl/Project3B/dataset1

# %%
# unzip the datasets to /content, so you don't risk going over the GDrive storage limit
# this can take a few minutes
# !unzip -q content/drive/Mydrive/Mldl/Project3B/sf_xs.zip -d /content/drive/MyDrive/Mldl/Project3B/dataset1
# Out:
# replace /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs/test/database/@0543037.38@4180974.80@10@S@037.77510@-122.51130@1ooZhwTQyuNt0xiue5YhLg@@134@@@@201311@@.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# now remove the zips from your GDrive
# %rm sf_xs.zip
# and move the unzipped datasets into your GDrive; in this way the next time
# you open Colab you can directly access them
# !mv /content/sf_xs /content/drive/MyDrive/dataset1

# %%
# now download the code. It is better if you fork this repo, so that you can push your
# modifications. Inside the repo folder you will also find logs of the experiments
# %cd /content/drive/MyDrive
# !git clone https://github.com/gmberton/CosPlace
# %cd /content/drive/MyDrive/CosPlace
# Out:
# Cloning into 'CosPlace'...
# remote: Enumerating objects: 248, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 248 (delta 98), reused 89 (delta 80), pack-reused 118
# Receiving objects: 100% (248/248), 69.02 KiB | 3.00 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
# /content/drive/MyDrive/CosPlace

# %% [markdown]
# ## Setup environment - every time

# %% [markdown]
# Every time you restart Colab's kernel, you have to re-install packages and download anything that was not saved into your GDrive

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd  /content/drive/MyDrive/Mldl/Project3B/CosPlace
# Out:
# /content/drive/MyDrive/Mldl/Project3B/CosPlace

# %%
# !pip install utm faiss_cpu
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 77.6 MB/s eta 0:00:00
# ...
#   Created wheel for utm: filename=utm-0.7.0-py3-none-any.whl size=6085 sha256=a60caaf9608294d248177ca6dcea5e3f588f54647e65555cc531d36f7b36fed8
#   Stored in directory: /root/.cache/pip/wheels/2f/a1/c8/543df0e8f5e824c3e92a432e32deb9cd89ae686095ee8cfcbe
# Successfully built utm
# ...

# %%
# !pip install kornia
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.7/705.7 kB 9.5 MB/s eta 0:00:00
# ...

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=1 --iterations_per_epoch=5 --num_preds_to_save 10

# %% [markdown]
# #Train with 5 epochs and 5000 iterations per epoch

# %%
# !python train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Mldl/Project3B/CosPlace/train.py", line 3, in <module>
#   File "/usr/local/lib/python3.10/dist-packages/torch/__init__.py", line 1465, in <module>
#     from . import _meta_registrations
#   File "/usr/local/lib/python3.10/dist-packages/torch/_meta_registrations.py", line 2705, in <module>
#     activate_meta()
#   File "/usr/local/lib/python3.10/dist-packages/torch/_meta_registrations.py", line 2667, in activate_meta
#     if torch._C._dispatch_has_kernel_for_dispatch_key(
# KeyboardInterrupt
# ^C

# %%
# !python train.py --resume_train /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-08-23_12-20-04/last_checkpoint.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10
# Out:
# 2023-08-28 08:03:53   train.py --resume_train /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-08-23_12-20-04/last_checkpoint.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10
# ...

# %% [markdown]
# Test on Tokyo datasets with 5 epochs and 5000 iterations per epoch

# %%
# !python3 eval.py --backbone ResNet18 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOK55000/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# Out:
# 2023-08-28 08:03:57   eval.py --backbone ResNet18 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOK55000/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# ...

# %% [markdown]
# # Backbones 5 epochs 5000 iterations

# %% [markdown]
# ##ResNet50

# %%
# !python train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10 --backbone ResNet50

# %%
# !python train.py --resume_train /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-08-24_12-12-24/last_checkpoint.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10 --backbone ResNet50
# Out:
# 2023-08-25 08:41:41   train.py --resume_train /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-08-24_12-12-24/last_checkpoint.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10 --backbone ResNet50
# ...

# %%
# !python3 eval.py --backbone ResNet50 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOKResNet50/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# Out:
# 2023-08-25 10:49:01   eval.py --backbone ResNet50 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOKResNet50/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# ...

# %% [markdown]
# #wide_resnet50_2

# %%
# !python train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10 --backbone wide_resnet50_2
# Out:
# 2023-08-25 12:40:54   train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10 --backbone wide_resnet50_2
# ...

# %%
# !python train.py --resume_train /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-08-26_12-33-24/last_checkpoint.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10 --backbone wide_resnet50_2

# %%
# !python3 eval.py --backbone wide_resnet50_2 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOKwide_resnet50_2/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs
# Out:
# 2023-08-27 13:49:21   eval.py --backbone wide_resnet50_2 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOKwide_resnet50_2/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs
# ...

# %%
# !python3 eval.py --backbone wide_resnet50_2 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOKwide_resnet50_2/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# Out:
# 2023-08-27 13:37:44   eval.py --backbone wide_resnet50_2 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOKwide_resnet50_2/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# ...

# %% [markdown]
# #densenet121

# %%
# !python train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10 --backbone densenet121

# %%
# !python train.py --resume_train /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-08-28_11-55-53/last_checkpoint.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10 --backbone densenet121

# %%
# !python3 eval.py --backbone densenet121 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOKdensenet121/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs
# Out:
# 2023-08-28 17:55:07   eval.py --backbone densenet121 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOKdensenet121/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs
# ...

# %%
# !python3 eval.py --backbone densenet121 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOKdensenet121/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# Out:
# 2023-08-28 18:08:22   eval.py --backbone densenet121 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOKdensenet121/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# ...

# %% [markdown]
# #VGG16

# %%
# !python train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10 --backbone VGG16
# Out:
# 2023-08-28 18:16:12   train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10 --backbone VGG16
# ...

# %%
# !python train.py --resume_train /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-08-29_08-01-26/last_checkpoint.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10 --backbone VGG16
# Out:
# 2023-08-29 11:57:16   train.py --resume_train /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-08-29_08-01-26/last_checkpoint.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs --groups_num 1 --epochs_num=5 --iterations_per_epoch=5000 --num_preds_to_save 10 --backbone VGG16
# ...

# %%
# !python3 eval.py --backbone VGG16 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOKVGG16/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# Out:
# 2023-08-29 14:27:50   eval.py --backbone VGG16 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/trainOKVGG16/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# ...

# %% [markdown]
# #Final test ok Tokyo

# %%
# !python3 eval.py --backbone VGG16 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/OKVGG16/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# Out:
# 2023-08-31 16:39:08   eval.py --backbone VGG16 --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/OKVGG16/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# ...

# %%
# !python3 eval.py --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/OKResNet18/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# Out:
# 2023-08-31 16:45:25   eval.py --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/OKResNet18/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# ...

# %%
# !python3 eval.py --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/horizontal_flip/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# Out:
# 2023-09-03 10:20:53   eval.py --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/horizontal_flip/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# ...

# %%
# !python3 eval.py --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/degree_10/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# Out:
# 2023-09-03 10:25:17   eval.py --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/degree_10/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# ...

# %%
# !python3 eval.py --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/degree_5/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# Out:
# 2023-09-03 10:26:22   eval.py --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/degree_5/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# ...

# %%
# !python3 eval.py --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-09-02_20-25-50/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# Out:
# 2023-09-03 12:20:45   eval.py --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-09-02_20-25-50/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/tokyo_xs
# ...

# %% [markdown]
# #Densnet121

# %%
# !python train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=10000 --num_preds_to_save 10 --backbone densenet121

# %% [markdown]
# #FullDataset
#
# ---

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --hue=0 --epochs_num=5 --iterations_per_epoch=10000
# Out:
# 2023-08-31 19:13:19   trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --hue=0 --epochs_num=5 --iterations_per_epoch=10000
# ...

# %%
# !python trainGG.py --resume_train /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-08-31_19-13-19/last_checkpoint.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=10000 --num_preds_to_save 10

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=10000 --num_preds_to_save 10 --degrees=10 --backbone=VGG16
# Out:
# 2023-09-03 14:22:00   trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=10000 --num_preds_to_save 10 --degrees=10 --backbone=VGG16
# ...

# %% [markdown]
# #Rerun of eval for data augmentation

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --num_preds_to_save 10

# %%
# !python eval.py --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-09-01_10-30-00/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g
# Out:
# 2023-09-01 11:15:15   eval.py --fc_output_dim 512 --resume_model /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-09-01_10-30-00/best_model.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g
# ...

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --degrees=5
# Out:
# 2023-09-01 11:39:01   trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --degrees=5
# ...

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --use_horizontal_flip=True
# Out:
# 2023-09-01 11:58:06   trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --use_horizontal_flip=True
# ...

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --degrees=10
# Out:
# 2023-09-01 12:22:35   trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --degrees=10
# ...

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --degrees=5 --use_horizontal_flip=True
# Out:
# 2023-09-01 13:08:44   trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --degrees=5 --use_horizontal_flip=True
# ...

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --brightness=0.5
# Out:
# 2023-09-01 13:53:24   trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --brightness=0.5
# ...

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --contrast=0.9
# Out:
# 2023-09-01 15:35:05   trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --contrast=0.9
# ...

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --contrast=0.5
# Out:
# 2023-09-01 16:43:13   trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --contrast=0.5
# ...

# %%
# !python trainGG.py --resume_train /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-09-01_16-43-13/last_checkpoint.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --contrast=0.5
# Out:
# 2023-09-01 19:29:07   trainGG.py --resume_train /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-09-01_16-43-13/last_checkpoint.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --contrast=0.5
# ...

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --satur=0.9
# Out:
# 2023-09-01 20:55:41   trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --satur=0.9
# ...

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --satur=0.5
# Out:
# 2023-09-01 21:31:57   trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --satur=0.5
# ...

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --hue=0.3
# Out:
# 2023-09-01 21:49:24   trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --hue=0.3
# ...

# %%
# !python trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --random_resized_crop=0
# Out:
# 2023-09-01 22:08:30   trainGG.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --random_resized_crop=0
# ...

# %% [markdown]
# #Optimizer

# %% [markdown]
# ##ASGD

# %%
# !python optim_train.py --resume_train /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-09-02_11-42-44/last_checkpoint.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500
# Out:
# 2023-09-02 12:41:35   optim_train.py --resume_train /content/drive/MyDrive/Mldl/Project3B/CosPlace/logs/default/2023-09-02_11-42-44/last_checkpoint.pth --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500
# ...

# %%
# !python optim_train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500

# %% [markdown]
# ##SGD

# %%
# !python optim_train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500
# Out:
# 2023-09-02 13:10:45   optim_train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500
# ...

# %% [markdown]
# ##AdamW

# %%
# !python optim_train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500
# Out:
# 2023-09-02 13:51:44   optim_train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500
# ...

# %%
# !python optim_train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --lr=1e-04
# Out:
# 2023-09-02 14:10:06   optim_train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --lr=1e-04
# ...

# %%
# !python optim_train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --lr=1e-06
# Out:
# 2023-09-02 14:30:07   optim_train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --lr=1e-06
# ...

# %% [markdown]
# #Adam

# %%
# !python optim_train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --lr=1e-04
# Out:
# 2023-09-03 10:37:25   optim_train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --lr=1e-04
# ...

# %%
# !python optim_train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --lr=1e-06
# Out:
# 2023-09-03 11:52:42   optim_train.py --dataset_folder /content/drive/MyDrive/Mldl/Project3B/dataset1/sf_xs_g --groups_num 1 --epochs_num=5 --iterations_per_epoch=500 --lr=1e-06
# ...
